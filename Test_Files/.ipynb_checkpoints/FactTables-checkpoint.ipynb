# %%
import os
import pyspark
import requests
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql.streaming import StreamingQueryException
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
spark = SparkSession.builder.appName("HiveSpark").enableHiveSupport().getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://itvdelab:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.8</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>HiveSpark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark.sql("DESCRIBE DEFAULT.test1_landing_table").toPandas()
# Out:
#                                col_name                  data_type comment
# 0                        reply_settings                     string    None
# 1                edit_history_tweet_ids              array<string>    None
# 2                     referenced_tweets  array<map<string,string>>    None
# 3                            created_at                  timestamp    None
# 4                                  lang                     string    None
# 5                                  text                     string    None
# 6                       conversation_id                     string    None
# 7                             author_id                     string    None
# 8                                    id                     string    None
# 9                              batch_id                        int    None
# 10                             hashtags              array<string>    None
# 11               attachments_media_keys              array<string>    None
# 12         public_metrics_retweet_count                     bigint    None
# 13           public_metrics_reply_count                     bigint    None
# 14            public_metrics_like_count                     bigint    None
# 15           public_metrics_quote_count                     bigint    None
# 16      public_metrics_impression_count                     bigint    None
# 17                    entities_mentions  array<map<string,string>>    None
# 18               user_profile_image_url                     string    None
# 19                 user_pinned_tweet_id                     string    None
# 20                        user_location                     string    None
# 21                       user_protected                    boolean    None
# 22                        user_verified                    boolean    None
# 23                     user_description                     string    None
# 24                            user_name                     string    None
# 25                              user_id                     string    None
# 26                        user_username                     string    None
# 27                      user_created_at                     string    None
# 28  user_public_metrics_followers_count                     bigint    None
# 29  user_public_metrics_following_count                     bigint    None
# 30      user_public_metrics_tweet_count                     bigint    None
# 31     user_public_metrics_listed_count                     bigint    None
# 32                      media_media_key                     string    None
# 33                           media_type                     string    None
# 34                  in_reply_to_user_id                     string    None
# 35                         geo_place_id                     string    None
# 36                           place_name                     string    None
# 37                     place_place_type                     string    None
# 38                             place_id                     string    None
# 39                   place_country_code                     string    None
# 40                      place_full_name                     string    None
# 41                        place_country                     string    None
# 42                       place_geo_type                     string    None
# 43                       place_geo_bbox                     string    None

# %%
pd.set_option('display.max_colwidth', None)
spark.sql("SELECT * FROM DEFAULT.test1_landing_table").toPandas()
# Out:
#      reply_settings edit_history_tweet_ids  \
# 0          everyone  [1653912312665743360]
# 1          everyone  [1653912307662192640]
# 2          everyone  [1653912300607406082]
# 3          everyone  [1653912260371423233]
# 4          everyone  [1653912199533064192]
# ...             ...                    ...
# 3488       everyone  [1653911925799936000]
# 3489       everyone  [1653911923568549888]
# 3490       everyone  [1653911921404309506]
# 3491       everyone  [1653911920657723392]
# 3492       everyone  [1653911913024110594]
#
#                                           referenced_tweets  \
# 0      [{'type': 'retweeted', 'id': '1653783978015350784'}]
# 1      [{'type': 'retweeted', 'id': '1651947583869206529'}]
# 2      [{'type': 'retweeted', 'id': '1653780430628311043'}]
# 3     [{'type': 'replied_to', 'id': '1653912257678692352'}]
# 4                                                        []
# ...                                                     ...
# 3488   [{'type': 'retweeted', 'id': '1631278389830070273'}]
# 3489                                                     []
# 3490   [{'type': 'retweeted', 'id': '1653624302074490880'}]
# 3491   [{'type': 'retweeted', 'id': '1653857901067350018'}]
# 3492                                                     []
#
#               created_at lang  \
# 0    2023-05-03 23:59:58   en
# 1    2023-05-03 23:59:57   en
# 2    2023-05-03 23:59:55   en
# 3    2023-05-03 23:59:45   en
# 4    2023-05-03 23:59:31   en
# ...                  ...  ...
# 3488 2023-05-03 23:58:25   en
# 3489 2023-05-03 23:58:25   en
# 3490 2023-05-03 23:58:24   en
# 3491 2023-05-03 23:58:24   en
# 3492 2023-05-03 23:58:22   en
#
#                                                                                                                                                                                                                                                                                       text  \
# 0                                                                                                                                             RT @ChildrensHD: “Don’t wait for someone else to fix this for you, electropollution is too dangerous for us, our children and our pollinato…
# 1                                                                                                                                                 RT @gooddollarorg: Thrilled to see @gooddollarorg was mentioned as an example of a #ReFI project generating new pathways for impact!  😍…
# 2                                                                                                                                              RT @HysSahin: I'm pleased to announce #Metatime is growing in numbers, and #technology is moving vast; we recognise that #Ghana is the new…
# 3                           Going back to an earlier thought that I had about the ways in which we have already merged humans with technology, here are some examples: contact lenses, pacemakers, hearing aids, cochlear implants and prosthetic limbs. #BCM325   https://t.co/BUcSABOM3l
# 4                                                 The HipHop Culture + Technology = #Web3Gang .....🗣We coming Deep‼️ It's time to make Music NFTS popping like it should be....where those that support get a piece of histor also....WHY NOT??  🗣 Keep watching 🫡 https://t.co/XlWTnxhuee
# ...                                                                                                                                                                                                                                                                                    ...
# 3488                                                                                                                                                                                                 RT @CruisingCorp: Morning! 👓 peak and have some fun #cruising https://t.co/vEDx4nIkql
# 3489  Exciting news for all #gambling and #crypto enthusiasts! Check out #GambleFi by @billionair_app and experience a revolutionary platform that combines #DeFi and #NFTs with online betting. Don't miss out on the $AIRB token and join the fun today! #blockchaingaming #onlinecasino
# 3490                                                                                                                                          RT @BlueFern22: (for fun - mid weights) corner CH 6H side swap airborne corner to corner  50% meter, you don't actually need to end with ai…
# 3491                                                                                                                                          RT @BerryDiaboli: We can have fun too, you know...  Made by Chili Cheese, our Lead Spriter! [Mad Rat Dead x Pizza Tower Mod] #PizzaTowerGam…
# 3492                                                                                                                                                                                 Life Is Precious So Value Your Time With Fun, Enjoyment &amp; Gettin Ta Da Money.." #BeKoolAndConquer
#
#           conversation_id            author_id                   id  batch_id  \
# 0     1653912312665743360  1040452177263620096  1653912312665743360         6
# 1     1653912307662192640           2599137816  1653912307662192640         6
# 2     1653912300607406082  1622559846066429952  1653912300607406082         6
# 3     1653912257678692352  1102121431582699520  1653912260371423233         6
# 4     1653912199533064192  1581107720748290048  1653912199533064192         6
# ...                   ...                  ...                  ...       ...
# 3488  1653911925799936000  1275036442788536323  1653911925799936000         3
# 3489  1653911923568549888  1586489402104111108  1653911923568549888         3
# 3490  1653911921404309506           2418097832  1653911921404309506         3
# 3491  1653911920657723392   897878875937677313  1653911920657723392         3
# 3492  1653911913024110594  1344712149290135552  1653911913024110594         3
#
#       ...  in_reply_to_user_id geo_place_id  place_name  place_place_type  \
# 0     ...                  NaN          NaN         NaN               NaN
# 1     ...                  NaN          NaN         NaN               NaN
# 2     ...                  NaN          NaN         NaN               NaN
# 3     ...  1102121431582699520          NaN         NaN               NaN
# 4     ...                  NaN          NaN         NaN               NaN
# ...   ...                  ...          ...         ...               ...
# 3488  ...                  NaN          NaN         NaN               NaN
# 3489  ...                  NaN          NaN         NaN               NaN
# 3490  ...                  NaN          NaN         NaN               NaN
# 3491  ...                  NaN          NaN         NaN               NaN
# 3492  ...                  NaN          NaN         NaN               NaN
#
#       place_id  place_country_code  place_full_name place_country  \
# 0          NaN                 NaN              NaN           NaN
# 1          NaN                 NaN              NaN           NaN
# 2          NaN                 NaN              NaN           NaN
# 3          NaN                 NaN              NaN           NaN
# 4          NaN                 NaN              NaN           NaN
# ...        ...                 ...              ...           ...
# 3488       NaN                 NaN              NaN           NaN
# 3489       NaN                 NaN              NaN           NaN
# 3490       NaN                 NaN              NaN           NaN
# 3491       NaN                 NaN              NaN           NaN
# 3492       NaN                 NaN              NaN           NaN
#
#      place_geo_type place_geo_bbox
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN            NaN
# ...             ...            ...
# 3488            NaN            NaN
# 3489            NaN            NaN
# 3490            NaN            NaN
# 3491            NaN            NaN
# 3492            NaN            NaN
#
# [3493 rows x 44 columns]

# %%
spark.sql('''set hive.exec.dynamic.partition=true''')

spark.sql('''set hive.exec.dynamic.partition.mode=nonstrict''')
# Out:
# +--------------------+---------+
# |                 key|    value|
# +--------------------+---------+
# |hive.exec.dynamic...|nonstrict|
# +--------------------+---------+

# %%
spark.sql("SELECT * FROM twitter_raw_data.tweet_data_raw").toPandas()
# Out:
#                 tweet_id            author_id  \
# 0    1653912285352435713           2504071885
# 1    1653912014908182528             72489795
# 2    1653911566989893633           2441327750
# 3    1653912261310775296           2802341658
# 4    1653911229046439939            407536905
# ..                   ...                  ...
# 621  1653912016745013249  1256736902922862594
# 622  1653911067855052802  1584008426543349760
# 623  1653911989557809154  1395279246642204672
# 624  1653912199989977091  1523991896753905665
# 625  1653911806790848513            558531724
#
#                                                                                                                                        tweet_text  \
# 0                                        The sun's bright glory scarce have learn'd to taste  #私人借贷 #民间借贷 #借贷 #急用钱怎么办 #网贷 https://t.co/Jq22b4LbPn
# 1    RT @anonotanon: #IStandWithKirralieSmith  "AVOs that are failing to keep women safe from male violence are now being used as weapons agains…
# 2    RT @BrandonWhit1ey: We've been working really hard at the #EvoBioCC team to develop a Mini Grant Program #EvoBioMGP. Our MGP is designed to…
# 3    RT @The_Pigeon: Happy birthday, Piggie! You're such a good friend, and life is more fun with you in it!   Celebrate with us by wishing Pigg…
# 4    RT @Rhyno_24: ⁦⁦@SharpNEC_UK⁩ are proud to once again, sponsor the @LTSMG_⁩ Conference!  Drop by, say hello, smash the pick ‘n’mix and mayb…
# ..                                                                                                                                            ...
# 621                                                RT @marmaguevo: i have to learn how to draw kumatora's hair.  #mother3 https://t.co/fIfHNlZyJj
# 622  RT @anonotanon: #IStandWithKirralieSmith  "AVOs that are failing to keep women safe from male violence are now being used as weapons agains…
# 623               RT @SubjectKpop: Tzuyu's Instagram update  "Thanks a lot, Sydney💘🫶Was it fun?"  #TWICE #트와이스 @JYPETWICE https://t.co/fc3CMmwsLn
# 624  RT @namoneyed: What can we say? Charlie warned them in English, Afrikaans, Setswana and Sipitori. In the famous words of Lindiwe Dlamini He…
# 625                                                                   #喉癌  Example recently lose game sport manage. 🤨💥🤐💯😀 https://t.co/OQnsNnI5XE
#
#                   hashtags_list retweet_count reply_count like_count  \
# 0                            []            10           7         10
# 1    [#IStandWithKirralieSmith]           152           0          0
# 2       [#EvoBioCC, #EvoBioMGP]             7           0          0
# 3                            []            43           0          0
# 4                            []             3           0          0
# ..                          ...           ...         ...        ...
# 621                  [#mother3]             8           0          0
# 622  [#IStandWithKirralieSmith]           152           0          0
# 623                    [#TWICE]          1402           0          0
# 624                          []             4           0          0
# 625                          []             0           0          0
#
#     qoute_count imperssion_count language           tweet_date  \
# 0             0                1       en  2023-05-03 23:59:51
# 1             0                0       en  2023-05-03 23:58:47
# 2             0                0       en  2023-05-03 23:57:00
# 3             0                0       en  2023-05-03 23:59:45
# 4             0                0       en  2023-05-03 23:55:39
# ..          ...              ...      ...                  ...
# 621           0                0       en  2023-05-03 23:58:47
# 622           0                0       en  2023-05-03 23:55:01
# 623           0                0       en  2023-05-03 23:58:41
# 624           0                0       en  2023-05-03 23:59:31
# 625           0                1       en  2023-05-03 23:57:57
#
#       who_can_reply  \
# 0          everyone
# 1          everyone
# 2          everyone
# 3    mentionedUsers
# 4          everyone
# ..              ...
# 621        everyone
# 622        everyone
# 623        everyone
# 624        everyone
# 625        everyone
#
#                                                                                         media_ids  \
# 0                                                                         [3_1653912234517512194]
# 1                                                                                              []
# 2                                                                                              []
# 3                                                                                              []
# 4                                                                                              []
# ..                                                                                            ...
# 621  [3_1653524348894937088, 3_1653524661370597378, 3_1653524761606082561, 3_1653524845857067008]
# 622                                                                                            []
# 623  [3_1653782175492497411, 3_1653782179057668097, 3_1653782181981085697, 3_1653782184640282624]
# 624                                                                                            []
# 625                                                                       [3_1653911764092739587]
#
#     tweet_location       edit_history_ids  year  month  day  hour
# 0              NaN  [1653912285352435713]  2023      5    3    23
# 1              NaN  [1653912014908182528]  2023      5    3    23
# 2              NaN  [1653911566989893633]  2023      5    3    23
# 3              NaN  [1653912261310775296]  2023      5    3    23
# 4              NaN  [1653911229046439939]  2023      5    3    23
# ..             ...                    ...   ...    ...  ...   ...
# 621            NaN  [1653912016745013249]  2023      5    3    23
# 622            NaN  [1653911067855052802]  2023      5    3    23
# 623            NaN  [1653911989557809154]  2023      5    3    23
# 624            NaN  [1653912199989977091]  2023      5    3    23
# 625            NaN  [1653911806790848513]  2023      5    3    23
#
# [626 rows x 19 columns]

# %%
spark.sql("SELECT * FROM twitter_raw_data.user_data_raw").toPandas()
# Out:
#                  user_id         username                         name  \
# 0    1635729937318711296    anarapilaaa77  ⚔️Anaa_Rapilaa⁵⚔️ | Suiswap
# 1    1622406099088318466    MirabilisGame                    Mirabilis
# 2             1450615531    anilkumartght                   buntykumar
# 3    1477569804730990593  naughtyme_69000                   Naughty Me
# 4    1640189306101968896   aidabubukcabai                  terviorvior
# ..                   ...              ...                          ...
# 527  1616624632336883712  anita_ramjattan              Anita ki sukoon
# 528  1501844469913722880  charles63709158                      charles
# 529             46413608    BritanniaMine             Britannia Museum
# 530            812768544     Drecx_Akhere          AKHERE DONALD (ADI)
# 531             23379362    DeanJFolkerts                Jean Folkerts
#
#                                                                                                                                                   profile_description  \
# 0                          🔥GA HUNTER/AIRDROP HUNTER🔥 🚀..This is are new acc✨(@AnaRapila777 and @Ana_Rapilaa77) has been SUSPENDED 📵❎  $MSTR // @SuiPadxyz #SuiPadxyz
# 1       Embark on an epic AI-generated open-world adventure in Mirabilis. Explore truley unique worlds, build your empire, conquer the multiverse. Developed on Flow.
# 2
# 3                                                                                    Im NO Artist | FAKER | 2d Enjoyer 🫡 | #NEARisNOW #NEARchan #MarmaJchan #Auctiano
# 4                                                                                                                                                       i'm reka 🙎‍♀️
# ..                                                                                                                                                                ...
# 527
# 528
# 529   Britannia Mine Museum, an award-winning National Historic Site, offers guided underground tours, theatre, historical and interactive exhibits and gold panning.
# 530                                                                                 DEFI _DEGEN COLLECTOR// COLLAB MANAGER//WEB3_FREAK// SPORT TRADER..#WAGMI #LFG 🚀🧨
# 531  Media,Journalism & Mass Communications Consultant. Experienced Professor with demonstrated history of success in journalism & masscomm education administration.
#
#                            location  \
# 0               Thai Dong, Thailand
# 1                         Metaverse
# 2                               NaN
# 3                               UwU
# 4                           she/her
# ..                              ...
# 527                             NaN
# 528                             NaN
# 529     Britannia Beach, BC, Canada
# 530  META VERSE / MANCHESTER UNITED
# 531                   Manhattan, KS
#
#                                                                                     profile_image  \
# 0                    https://pbs.twimg.com/profile_images/1645823227326001154/AuXkkkvj_normal.jpg
# 1                    https://pbs.twimg.com/profile_images/1622407733281525761/fGpT5Ilm_normal.jpg
# 2                  https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png
# 3                    https://pbs.twimg.com/profile_images/1557773444124913664/rKaCp_r9_normal.jpg
# 4                    https://pbs.twimg.com/profile_images/1653204399240671232/9G6JoCjr_normal.jpg
# ..                                                                                            ...
# 527                  https://pbs.twimg.com/profile_images/1649783867694350337/RpIkuDGR_normal.jpg
# 528                  https://pbs.twimg.com/profile_images/1501844587949744128/kECO1uAt_normal.png
# 529  https://pbs.twimg.com/profile_images/2767513828/3d5fd827ba7b6d8024f406222e341416_normal.jpeg
# 530                  https://pbs.twimg.com/profile_images/1619024889091952641/uFAFKJLK_normal.jpg
# 531                   https://pbs.twimg.com/profile_images/811198349022023685/hrKTlKk8_normal.jpg
#
#          pinned_tweet_id     profile_creation_date protected verfied  \
# 0    1635739085510959104  2023-03-14T19:50:20.000Z     false   false
# 1    1648496006827487232  2023-02-06T01:25:44.000Z     false   false
# 2                    NaN  2013-05-23T05:10:30.000Z     false   false
# 3                    NaN  2022-01-02T09:18:17.000Z     false   false
# 4    1640505653168066560  2023-03-27T03:09:48.000Z     false   false
# ..                   ...                       ...       ...     ...
# 527                  NaN  2023-01-21T02:32:40.000Z     false   false
# 528                  NaN  2022-03-10T08:57:07.000Z     false   false
# 529                  NaN  2009-06-11T15:39:57.000Z     false   false
# 530                  NaN  2012-09-09T09:33:53.000Z     false   false
# 531                  NaN  2009-03-09T00:50:28.000Z     false   false
#
#     followers_count following_count tweet_count listed_count user_popularity  \
# 0                59            1140        3193            3             Low
# 1                23             116         127            1             Low
# 2                 0               2        1100            0             Low
# 3               136              96         827            0             Low
# 4                33            1540        8280            1             Low
# ..              ...             ...         ...          ...             ...
# 527              54              22       31613            0             Low
# 528              59             123       11785            0             Low
# 529            3326            2949        3650          157          Middle
# 530            1302            1879        5259            4          Middle
# 531             714             790        4916           58             Low
#
#      year  month  day  hour
# 0    2023      5    3    23
# 1    2023      5    3    23
# 2    2023      5    3    23
# 3    2023      5    3    23
# 4    2023      5    3    23
# ..    ...    ...  ...   ...
# 527  2023      5    3    23
# 528  2023      5    3    23
# 529  2023      5    3    23
# 530  2023      5    3    23
# 531  2023      5    3    23
#
# [532 rows x 19 columns]

# %%
spark.sql("SELECT * FROM twitter_raw_data.place_data_raw").toPandas()
# Out:
#   place_id place_name place_fullname place_country place_country_code  \
# 0      NaN        NaN            NaN           NaN                NaN
#
#   place_type  year  month  day  hour
# 0        NaN  2023      5    3    23

# %%
spark.sql("SELECT * FROM twitter_raw_data.media_data_raw").toPandas()
# Out:
#                  media_id media_type  year  month  day  hour
# 0   3_1653912038442258433      photo  2023      5    3    23
# 1   3_1653911407463890944      photo  2023      5    3    23
# 2   3_1653911882741293057      photo  2023      5    3    23
# 3                     NaN        NaN  2023      5    3    23
# 4   7_1653911823710834690      video  2023      5    3    23
# ..                    ...        ...   ...    ...  ...   ...
# 77  3_1653912085510893568      photo  2023      5    3    23
# 78  3_1653910793023557632      photo  2023      5    3    23
# 79  3_1653911918690865153      photo  2023      5    3    23
# 80  3_1653912012542574592      photo  2023      5    3    23
# 81  3_1653911052097290240      photo  2023      5    3    23
#
# [82 rows x 6 columns]

# %%
spark.sql("DESCRIBE twitter_raw_data.tweet_data_raw").toPandas()
# Out:
#                    col_name      data_type  comment
# 0                  tweet_id         string     None
# 1                 author_id         string     None
# 2                tweet_text         string     None
# 3             hashtags_list  array<string>     None
# 4             retweet_count         string     None
# 5               reply_count         string     None
# 6                like_count         string     None
# 7               qoute_count         string     None
# 8          imperssion_count         string     None
# 9                  language         string     None
# 10               tweet_date         string     None
# 11            who_can_reply         string     None
# 12                media_ids  array<string>     None
# 13           tweet_location         string     None
# 14         edit_history_ids  array<string>     None
# 15                     year            int     None
# 16                    month            int     None
# 17                      day            int     None
# 18                     hour            int     None
# 19  # Partition Information
# 20               # col_name      data_type  comment
# 21                     year            int     None
# 22                    month            int     None
# 23                      day            int     None
# 24                     hour            int     None

# %%
spark.sql("DESCRIBE twitter_raw_data.user_data_raw").toPandas()
# Out:
#                    col_name  data_type  comment
# 0                   user_id     string     None
# 1                  username     string     None
# 2                      name     string     None
# 3       profile_description     string     None
# 4                  location     string     None
# 5             profile_image     string     None
# 6           pinned_tweet_id     string     None
# 7     profile_creation_date     string     None
# 8                 protected     string     None
# 9                   verfied     string     None
# 10          followers_count     string     None
# 11          following_count     string     None
# 12              tweet_count     string     None
# 13             listed_count     string     None
# 14          user_popularity     string     None
# 15                     year        int     None
# 16                    month        int     None
# 17                      day        int     None
# 18                     hour        int     None
# 19  # Partition Information
# 20               # col_name  data_type  comment
# 21                     year        int     None
# 22                    month        int     None
# 23                      day        int     None
# 24                     hour        int     None

# %%
spark.sql("DESCRIBE twitter_raw_data.place_data_raw").toPandas()
# Out:
#                    col_name  data_type  comment
# 0                  place_id     string     None
# 1                place_name     string     None
# 2            place_fullname     string     None
# 3             place_country     string     None
# 4        place_country_code     string     None
# 5                place_type     string     None
# 6                      year        int     None
# 7                     month        int     None
# 8                       day        int     None
# 9                      hour        int     None
# 10  # Partition Information
# 11               # col_name  data_type  comment
# 12                     year        int     None
# 13                    month        int     None
# 14                      day        int     None
# 15                     hour        int     None

# %%
spark.sql("DESCRIBE twitter_raw_data.media_data_raw").toPandas()
# Out:
#                    col_name  data_type  comment
# 0                  media_id     string     None
# 1                media_type     string     None
# 2                      year        int     None
# 3                     month        int     None
# 4                       day        int     None
# 5                      hour        int     None
# 6   # Partition Information
# 7                # col_name  data_type  comment
# 8                      year        int     None
# 9                     month        int     None
# 10                      day        int     None
# 11                     hour        int     None
